# %% [markdown]
# # Modeling with GNN-ePC-SAFT

# %% [markdown]
# Model combining graph neural network with ePC-SAFT

# %% [markdown]
# ## Starting point

# %%
# %pip install rdkit torchmetrics ml-collections polars clu jraph jaxopt -q
# %pip install torch_geometric -q
# %pip install pcsaft

# %%
# %pip show pcsaft | grep Version

# %%
import wandb
import os

# %%
wandb.login()

# %%
# !python train.py --workdir=./ --config=configs/default.py \
--config.num_train_steps=1000000 --config.log_every_steps=100 --config.num_para=3 \
--config.checkpoint_every_steps=2000 --config.learning_rate=0.001 --config.patience=10 \
--config.warmup_steps=500 --config.optimizer={'adam'} --config.batch_size=128 \
--config.propagation_depth=3 --config.hidden_dim=64 --config.num_mlp_layers=2 --config.pre_layers=2 --config.post_layers=1

# %%
# !python evaluate.py --workdir=./ --config=configs/default.py \
--config.num_train_steps=1000000 --config.log_every_steps=100 --config.num_para=3 \
--config.checkpoint_every_steps=2000 --config.learning_rate=0.001 --config.patience=10 \
--config.warmup_steps=500 --config.optimizer={'adam'} --config.batch_size=128 \
--config.propagation_depth=3 --config.hidden_dim=64 --config.num_mlp_layers=2 --config.pre_layers=2 --config.post_layers=1
# Out:
# data: 100%|███████████████████████████████| 1800/1800 [00:00<00:00, 6538.18it/s]
# data: 100%|██████████████████████████████| 1800/1800 [00:00<00:00, 34556.57it/s]
# I0808 04:00:42.918683 140231737964352 xla_bridge.py:355] Unable to initialize backend 'tpu_driver': NOT_FOUND: Unable to find driver in registry given worker:
# I0808 04:00:43.302195 140231737964352 xla_bridge.py:355] Unable to initialize backend 'rocm': NOT_FOUND: Could not find registered platform with name: "rocm". Available platform names are: Interpreter Host CUDA
# I0808 04:00:43.302982 140231737964352 xla_bridge.py:355] Unable to initialize backend 'tpu': module 'jaxlib.xla_extension' has no attribute 'get_tpu_client'
# I0808 04:00:43.303251 140231737964352 xla_bridge.py:355] Unable to initialize backend 'plugin': xla_extension has no attributes named get_plugin_device_client. Compile TensorFlow with //tensorflow/compiler/xla/python:enable_plugin_device set to true (defaults to false) to enable this.
# I0808 04:00:43.303440 140231737964352 evaluate.py:207] JAX host: 0 / 1
# I0808 04:00:43.303575 140231737964352 evaluate.py:208] JAX local devices: [StreamExecutorGpuDevice(id=0, process_index=0, slice_index=0)]
# I0808 04:00:43.303689 140231737964352 evaluate.py:210] Calling evaluate
# wandb: Currently logged in as: wildsonbbl (wildson). Use `wandb login --relogin` to force relogin
# I0808 04:00:45.722537 140231737964352 evaluate.py:59] Obtaining datasets.
# I0808 04:00:46.771057 140231737964352 evaluate.py:75] Initializing network.
# wandb: wandb version 0.15.8 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.4
# wandb: Run data is saved locally in /workspaces/ePC-SAFT/wandb/run-20230808_040056-3sey25st
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run winter-plant-607
# wandb: ⭐️ View project at https://wandb.ai/wildson/gnn-pc-saft
# wandb: 🚀 View run at https://wandb.ai/wildson/gnn-pc-saft/runs/3sey25st
# wandb: Waiting for W&B process to finish... (success).
# wandb: | 0.008 MB of 0.008 MB uploaded (0.000 MB deduped)
# wandb: Run history:
# wandb:      huber_den ▁▁▄▂▁▁▁▁▁▂▁▂▄▁▆▃▇▃█▂▁▃▇▂▂▄▄▁▅▃▃▁▇▂█▂█▇▁▅
# wandb:       huber_vp █▂▃▁▁▁▁▁▁▁▁▄▃▁▁▁▁▂▂▂▁▁▁▂▄▁▁▆▁▁▁▆▂▂▇▁▁▆▂▂
# wandb:       mape_den ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▂▁▃▁▁▁▂▁▁▂▂▁▂▁▂▁▂▁▃▁▃▃▁█
# wandb:        mape_vp ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁▁▁▁▁▁▁
# wandb: test_huber_den ▁
# wandb:  test_huber_vp ▁
# wandb:  test_mape_den ▁
# wandb:   test_mape_vp ▁
# wandb:  val_huber_den ▁
# wandb:   val_huber_vp ▁
# wandb:   val_mape_den ▁
# wandb:    val_mape_vp ▁
# wandb:
# wandb: Run summary:
# wandb:      huber_den 441.01447
# wandb:       huber_vp 1.70081
# wandb:       mape_den 0.18781
# wandb:        mape_vp 0.13675
# wandb: test_huber_den 1023.18048
# wandb:  test_huber_vp 60601.14453
# wandb:  test_mape_den 0.16423
# wandb:   test_mape_vp 93379880.0
# wandb:  val_huber_den 255.4254
# wandb:   val_huber_vp 25857.24023
# wandb:   val_mape_den 0.02066
# wandb:    val_mape_vp 0.19875
# wandb:
# wandb: Synced winter-plant-607: https://wandb.ai/wildson/gnn-pc-saft/runs/3sey25st
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230808_040056-3sey25st/logs
